# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.1/910.1 kB 17.5 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/EuroSAT_RGB_split_64.16.20.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2745.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2746.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2747.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2748.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2749.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_275.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2750.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2751.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2752.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2754.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2756.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_2757.jpg
#   inflating: EuroSAT_RGB_split_64.16.20/train/SeaLake/SeaLake_276.jpg
# ...

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data='/content/EuroSAT_RGB_split_64.16.20', epochs=30, imgsz=64)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 86.6MB/s]
# Ultralytics 8.3.62 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Inference

# %%
from IPython.display import Image

# %%
Image("/content/runs/classify/train/results.png", width=600)

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
# Out:
# Ultralytics 8.3.62 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# train: /content/EuroSAT_RGB_split_64.16.20/train... found 17280 images in 10 classes ✅
# val: /content/EuroSAT_RGB_split_64.16.20/val... found 4320 images in 10 classes ✅
# test: /content/EuroSAT_RGB_split_64.16.20/test... found 5400 images in 10 classes ✅
# val: Scanning /content/EuroSAT_RGB_split_64.16.20/val... 4320 images, 0 corrupt: 100%|██████████| 4320/4320 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 270/270 [00:03<00:00, 85.90it/s]
#                    all      0.973          1
# Speed: 0.0ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val3

# %%
metrics = model.val(split = "test")
# Out:
# Ultralytics 8.3.62 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# train: /content/EuroSAT_RGB_split_64.16.20/train... found 17280 images in 10 classes ✅
# val: /content/EuroSAT_RGB_split_64.16.20/val... found 4320 images in 10 classes ✅
# test: /content/EuroSAT_RGB_split_64.16.20/test... found 5400 images in 10 classes ✅
# test: Scanning /content/EuroSAT_RGB_split_64.16.20/test... 5400 images, 0 corrupt: 100%|██████████| 5400/5400 [00:00<00:00, 5588.37it/s]
# test: New cache created: /content/EuroSAT_RGB_split_64.16.20/test.cache
#                classes   top1_acc   top5_acc: 100%|██████████| 338/338 [00:03<00:00, 86.33it/s]
#                    all      0.967          1
# Speed: 0.0ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val3

# %%
# !zip -r  /content/runs/classify/classify.zip /content/runs/classify
# Out:
#   adding: content/runs/classify/ (stored 0%)
#   adding: content/runs/classify/val2/ (stored 0%)
#   adding: content/runs/classify/val2/val_batch0_labels.jpg (deflated 4%)
#   adding: content/runs/classify/val2/confusion_matrix_normalized.png (deflated 19%)
#   adding: content/runs/classify/val2/val_batch2_labels.jpg (deflated 3%)
#   adding: content/runs/classify/val2/val_batch2_pred.jpg (deflated 3%)
#   adding: content/runs/classify/val2/val_batch1_labels.jpg (deflated 3%)
#   adding: content/runs/classify/val2/val_batch1_pred.jpg (deflated 3%)
#   adding: content/runs/classify/val2/confusion_matrix.png (deflated 21%)
#   adding: content/runs/classify/val2/val_batch0_pred.jpg (deflated 5%)
#   adding: content/runs/classify/.ipynb_checkpoints/ (stored 0%)
#   adding: content/runs/classify/val3/ (stored 0%)
#   adding: content/runs/classify/val3/val_batch0_labels.jpg (deflated 6%)
#   adding: content/runs/classify/val3/confusion_matrix_normalized.png (deflated 19%)
# ...

# %%
model = YOLO('/content/runs/classify/train/weights/best.pt')

results = model("/content/EuroSAT_RGB_split_64.16.20/test/Forest/Forest_1006.jpg") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/EuroSAT_RGB_split_64.16.20/test/Forest/Forest_1006.jpg: 64x64 Forest 1.00, SeaLake 0.00, AnnualCrop 0.00, Pasture 0.00, River 0.00, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
#  names: {0: 'AnnualCrop', 1: 'Forest', 2: 'HerbaceousVegetation', 3: 'Highway', 4: 'Industrial', 5: 'Pasture', 6: 'PermanentCrop', 7: 'Residential', 8: 'River', 9: 'SeaLake'}
#  obb: None
#  orig_img: array([[[ 74, 105,  50],
#          [ 74, 105,  50],
#          [ 74, 105,  50],
#          ...,
#          [ 81, 115,  55],
#          [ 82, 115,  58],
#          [ 76, 109,  52]],
#
#         [[ 74, 105,  50],
#          [ 74, 105,  50],
#          [ 74, 105,  50],
#          ...,
#          [ 81, 115,  55],
#          [ 82, 115,  58],
#          [ 76, 109,  52]],
#
#         [[ 77, 108,  53],
#          [ 78, 109,  54],
#          [ 77, 105,  52],
#          ...,
#          [ 80, 114,  54],
#          [ 78, 110,  55],
#          [ 80, 111,  56]],
#
#         ...,
#
#         [[ 69,  86,  52],
#          [ 68,  85,  51],
#          [ 70,  84,  50],
#          ...,
# ...
